# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from transformers import RobertaTokenizer
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score

# 初始化数组，用于存储结果
accuracies = np.zeros(10)
f1_scores = np.zeros(10)

# 加载数据并进行预处理
df = pd.read_csv('data.csv')
df.dropna(inplace=True)  # 删除包含NaN的行
df['label'] = LabelEncoder().fit_transform(df['label'])  # 将标签编码为整数

# 使用RobertaTokenizer进行文本编码
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
encoded = tokenizer(df['phrase'].tolist(), padding='max_length', truncation=True, max_length=64, return_tensors="tf")
input_ids = encoded['input_ids'].numpy()  # 将编码后的input_ids转换为NumPy数组

# 数据集划分为训练集和测试集
train_input_ids, test_input_ids, train_labels, test_labels = train_test_split(
    input_ids, df['label'].values, test_size=0.2, random_state=42
)

# 定义模型参数
vocab_size = tokenizer.vocab_size
embedding_dim = 64
lstm_units = 64
num_classes = df['label'].nunique()

for i in range(10):
    # 构建模型
    input_layer = Input(shape=(64,), dtype='int32', name='input_ids')
    embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=64)(input_layer)
    lstm_layer1 = LSTM(lstm_units, return_sequences=True)(embedding_layer)
    lstm_layer2 = LSTM(lstm_units, return_sequences=True)(lstm_layer1)
    lstm_layer3 = LSTM(lstm_units)(lstm_layer2)
    dense_layer1 = Dense(128, activation='relu')(lstm_layer3)  # 第一个全连接层
    dense_layer2 = Dense(64, activation='relu')(dense_layer1)  # 第二个全连接层
    output_layer = Dense(num_classes, activation='softmax')(dense_layer2)
    model = Model(inputs=input_layer, outputs=output_layer)

    # 编译模型
    model.compile(optimizer=Adam(learning_rate=2e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # 准备训练数据
    train_dataset = tf.data.Dataset.from_tensor_slices((train_input_ids, train_labels)).batch(32)

    # 训练模型
    model.fit(train_dataset, epochs=15)

    # 进行预测
    test_predictions = model.predict(test_input_ids)
    predicted_labels = np.argmax(test_predictions, axis=1)

    # 计算准确度和F1得分
    accuracies[i] = accuracy_score(test_labels, predicted_labels)
    f1_scores[i] = f1_score(test_labels, predicted_labels, average='macro')

# 计算平均准确度和F1得分
average_accuracy = np.mean(accuracies)
average_f1_score = np.mean(f1_scores)

# 输出模型性能
print(f"average_accuracy: {average_accuracy:.4f}")
print(f"average_f1_score: {average_f1_score:.4f}")
# Out:
# C:\Users\32366\miniconda3\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Epoch 1/15
# 1528/1528 [==============================] - 17s 10ms/step - loss: 1.0645 - accuracy: 0.4027
# Epoch 2/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.9218 - accuracy: 0.5121
# Epoch 3/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.8117 - accuracy: 0.5984
# Epoch 4/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.7111 - accuracy: 0.6772
# Epoch 5/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.6332 - accuracy: 0.7295
# Epoch 6/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.5741 - accuracy: 0.7654
# Epoch 7/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.5277 - accuracy: 0.7898
# Epoch 8/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4895 - accuracy: 0.8078
# Epoch 9/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4596 - accuracy: 0.8200
# Epoch 10/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4352 - accuracy: 0.8311
# Epoch 11/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4142 - accuracy: 0.8424
# Epoch 12/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3961 - accuracy: 0.8522
# Epoch 13/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3803 - accuracy: 0.8605
# Epoch 14/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3683 - accuracy: 0.8672
# Epoch 15/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3577 - accuracy: 0.8718
# 382/382 [==============================] - 2s 4ms/step
# Epoch 1/15
# 1528/1528 [==============================] - 18s 11ms/step - loss: 1.0841 - accuracy: 0.3791
# Epoch 2/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.9586 - accuracy: 0.4947
# Epoch 3/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.8515 - accuracy: 0.5658
# Epoch 4/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.7530 - accuracy: 0.6393
# Epoch 5/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.6663 - accuracy: 0.7067
# Epoch 6/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.5945 - accuracy: 0.7539
# Epoch 7/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.5382 - accuracy: 0.7882
# Epoch 8/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4926 - accuracy: 0.8133
# Epoch 9/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4547 - accuracy: 0.8325
# Epoch 10/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4212 - accuracy: 0.8465
# Epoch 11/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.3921 - accuracy: 0.8577
# Epoch 12/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.3668 - accuracy: 0.8672
# Epoch 13/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.3444 - accuracy: 0.8742
# Epoch 14/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.3245 - accuracy: 0.8808
# Epoch 15/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.3086 - accuracy: 0.8872
# 382/382 [==============================] - 2s 4ms/step
# Epoch 1/15
# 1528/1528 [==============================] - 18s 10ms/step - loss: 1.0557 - accuracy: 0.4080
# Epoch 2/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.8963 - accuracy: 0.5380
# Epoch 3/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.7730 - accuracy: 0.6514
# Epoch 4/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.6688 - accuracy: 0.7184
# Epoch 5/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.5902 - accuracy: 0.7651
# Epoch 6/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.5323 - accuracy: 0.7956
# Epoch 7/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.4891 - accuracy: 0.8186
# Epoch 8/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.4554 - accuracy: 0.8336
# Epoch 9/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.4284 - accuracy: 0.8465
# Epoch 10/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.4064 - accuracy: 0.8565
# Epoch 11/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.3887 - accuracy: 0.8629
# Epoch 12/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3743 - accuracy: 0.8683
# Epoch 13/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3619 - accuracy: 0.8729
# Epoch 14/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3536 - accuracy: 0.8757
# Epoch 15/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3461 - accuracy: 0.8771
# 382/382 [==============================] - 2s 4ms/step
# Epoch 1/15
# 1528/1528 [==============================] - 18s 11ms/step - loss: 1.0755 - accuracy: 0.3993
# Epoch 2/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.9317 - accuracy: 0.5127
# Epoch 3/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.8136 - accuracy: 0.6028
# Epoch 4/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.7085 - accuracy: 0.6814
# Epoch 5/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.6227 - accuracy: 0.7396
# Epoch 6/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.5582 - accuracy: 0.7795
# Epoch 7/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.5095 - accuracy: 0.8067
# Epoch 8/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4712 - accuracy: 0.8277
# Epoch 9/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4406 - accuracy: 0.8417
# Epoch 10/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4145 - accuracy: 0.8538
# Epoch 11/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.3936 - accuracy: 0.8626
# Epoch 12/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.3763 - accuracy: 0.8689
# Epoch 13/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3627 - accuracy: 0.8730
# Epoch 14/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.3515 - accuracy: 0.8762
# Epoch 15/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.3436 - accuracy: 0.8781
# 382/382 [==============================] - 2s 4ms/step
# Epoch 1/15
# 1528/1528 [==============================] - 18s 11ms/step - loss: 1.0666 - accuracy: 0.3952
# Epoch 2/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.9267 - accuracy: 0.5056
# Epoch 3/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.8339 - accuracy: 0.5641
# Epoch 4/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.7466 - accuracy: 0.6395
# Epoch 5/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.6570 - accuracy: 0.7154
# Epoch 6/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.5860 - accuracy: 0.7646
# Epoch 7/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.5339 - accuracy: 0.7953
# Epoch 8/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4945 - accuracy: 0.8164
# Epoch 9/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.4631 - accuracy: 0.8321
# Epoch 10/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4353 - accuracy: 0.8448
# Epoch 11/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4125 - accuracy: 0.8549
# Epoch 12/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.3927 - accuracy: 0.8634
# Epoch 13/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.3757 - accuracy: 0.8702
# Epoch 14/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.3620 - accuracy: 0.8759
# Epoch 15/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.3504 - accuracy: 0.8794
# 382/382 [==============================] - 2s 4ms/step
# Epoch 1/15
# 1528/1528 [==============================] - 19s 11ms/step - loss: 1.0728 - accuracy: 0.3857
# Epoch 2/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.9218 - accuracy: 0.5046
# Epoch 3/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.8239 - accuracy: 0.5513
# Epoch 4/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.7519 - accuracy: 0.5805
# Epoch 5/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.7012 - accuracy: 0.5992
# Epoch 6/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.6625 - accuracy: 0.6259
# Epoch 7/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.6166 - accuracy: 0.6796
# Epoch 8/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.5637 - accuracy: 0.7338
# Epoch 9/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.5173 - accuracy: 0.7715
# Epoch 10/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4786 - accuracy: 0.7981
# Epoch 11/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4476 - accuracy: 0.8163
# Epoch 12/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.4228 - accuracy: 0.8290
# Epoch 13/15
# 1528/1528 [==============================] - 16s 11ms/step - loss: 0.4019 - accuracy: 0.8394
# Epoch 14/15
# 1528/1528 [==============================] - 17s 11ms/step - loss: 0.3839 - accuracy: 0.8490
# Epoch 15/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3683 - accuracy: 0.8577
# 382/382 [==============================] - 2s 4ms/step
# Epoch 1/15
# 1528/1528 [==============================] - 18s 10ms/step - loss: 1.0803 - accuracy: 0.3875
# Epoch 2/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.9200 - accuracy: 0.5322
# Epoch 3/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.7879 - accuracy: 0.6419
# Epoch 4/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.6816 - accuracy: 0.7102
# Epoch 5/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.6011 - accuracy: 0.7589
# Epoch 6/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.5419 - accuracy: 0.7911
# Epoch 7/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4967 - accuracy: 0.8158
# Epoch 8/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4614 - accuracy: 0.8329
# Epoch 9/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4323 - accuracy: 0.8471
# Epoch 10/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4074 - accuracy: 0.8570
# Epoch 11/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3864 - accuracy: 0.8649
# Epoch 12/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3675 - accuracy: 0.8712
# Epoch 13/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3512 - accuracy: 0.8762
# Epoch 14/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3373 - accuracy: 0.8810
# Epoch 15/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3265 - accuracy: 0.8842
# 382/382 [==============================] - 2s 4ms/step
# Epoch 1/15
# 1528/1528 [==============================] - 18s 10ms/step - loss: 1.0749 - accuracy: 0.3986
# Epoch 2/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.9226 - accuracy: 0.5313
# Epoch 3/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.7930 - accuracy: 0.6362
# Epoch 4/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.6847 - accuracy: 0.7097
# Epoch 5/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.5996 - accuracy: 0.7612
# Epoch 6/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.5347 - accuracy: 0.7963
# Epoch 7/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4839 - accuracy: 0.8228
# Epoch 8/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4432 - accuracy: 0.8431
# Epoch 9/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4096 - accuracy: 0.8580
# Epoch 10/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3809 - accuracy: 0.8706
# Epoch 11/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3553 - accuracy: 0.8820
# Epoch 12/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3333 - accuracy: 0.8908
# Epoch 13/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3147 - accuracy: 0.8973
# Epoch 14/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.2994 - accuracy: 0.9021
# Epoch 15/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.2868 - accuracy: 0.9061
# 382/382 [==============================] - 2s 4ms/step
# Epoch 1/15
# 1528/1528 [==============================] - 18s 10ms/step - loss: 1.0597 - accuracy: 0.4089
# Epoch 2/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.8956 - accuracy: 0.5507
# Epoch 3/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.7709 - accuracy: 0.6504
# Epoch 4/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.6661 - accuracy: 0.7207
# Epoch 5/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.5859 - accuracy: 0.7670
# Epoch 6/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.5270 - accuracy: 0.8004
# Epoch 7/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4813 - accuracy: 0.8239
# Epoch 8/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4453 - accuracy: 0.8417
# Epoch 9/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4161 - accuracy: 0.8561
# Epoch 10/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3919 - accuracy: 0.8669
# Epoch 11/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3717 - accuracy: 0.8750
# Epoch 12/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3540 - accuracy: 0.8825
# Epoch 13/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3398 - accuracy: 0.8876
# Epoch 14/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3273 - accuracy: 0.8910
# Epoch 15/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3175 - accuracy: 0.8940
# 382/382 [==============================] - 2s 4ms/step
# Epoch 1/15
# 1528/1528 [==============================] - 18s 11ms/step - loss: 1.0655 - accuracy: 0.4048
# Epoch 2/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.9247 - accuracy: 0.5127
# Epoch 3/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.8115 - accuracy: 0.5976
# Epoch 4/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.7133 - accuracy: 0.6717
# Epoch 5/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.6342 - accuracy: 0.7271
# Epoch 6/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.5717 - accuracy: 0.7663
# Epoch 7/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.5237 - accuracy: 0.7942
# Epoch 8/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4870 - accuracy: 0.8133
# Epoch 9/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4566 - accuracy: 0.8270
# Epoch 10/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.4311 - accuracy: 0.8373
# Epoch 11/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.4090 - accuracy: 0.8454
# Epoch 12/15
# 1528/1528 [==============================] - 15s 10ms/step - loss: 0.3907 - accuracy: 0.8528
# Epoch 13/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3766 - accuracy: 0.8580
# Epoch 14/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3673 - accuracy: 0.8629
# Epoch 15/15
# 1528/1528 [==============================] - 16s 10ms/step - loss: 0.3619 - accuracy: 0.8668
# 382/382 [==============================] - 2s 4ms/step
# average_accuracy: 0.7704
# average_f1_score: 0.7732
